# %%
# file handling

# x --> create file 
# r --> read model
# w --> write model(override)
# a --> write model(without override)
# rb--> to read a image in a file.

# %%
f1=open("abc.txt",'x')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 f1=open("abc.txt",'x')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'abc.txt'

# %%
f2=open("abc.txt",'w')

# %%
f2.write("this is krishna")
# Out:
# 15

# %%
f2.close()

# %%
f3=open("abc.txt",'w')

# %%
f3.writelines("this is python 6pm .")

# %%
f3.close()

# %%
f3.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 f3.read()
#
# ValueError: I/O operation on closed file.

# %%
f4=open("abc.txt",'a')

# %%
f4.write("this is krishna")
# Out:
# 15

# %%
f4.close()

# %%
f5=open("xyz.txt",'a')

# %%
f5.write("this is krishna")
# Out:
# 15

# %%
f5.write("this is python batch")
# Out:
# 20

# %%
f5.write("this is python class")
# Out:
# 20

# %%
f5.close()

# %%
f6=open("xyz.txt",'a')

# %%
f6.write("\nthis is krishna")
# Out:
# 16

# %%
f6.close()

# %%
f7=open("xyz.txt",'r')

# %%
f7.read(20)
# Out:
# 'this is krishnathis '

# %%
f7.read(20)
# Out:
# 'is python batchthis '

# %%
f7.read(10)
# Out:
# 'is python '

# %%
f7.seek(0)
# Out:
# 0

# %%
f7.read(20)
# Out:
# 'this is krishnathis '

# %%
f7.close()

# %%
f8=open("image.jpg","rb")

# %%
f8.readlines()
# Out:
# [b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x02\x02\x02\x03\x02\x02\x02\x03\x03\x03\x03\x04\x06\x04\x04\x04\x04\x04\x08\x06\x06\x05\x06\t\x08\n',
#  b'\n',
#  b'\t\x08\t\t\n',
#  b'\x0c\x0f\x0c\n',
#  b'\x0b\x0e\x0b\t\t\r\x11\r\x0e\x0f\x10\x10\x11\x10\n',
#  b'\x0c\x12\x13\x12\x10\x13\x0f\x10\x10\x10\xff\xdb\x00C\x01\x03\x03\x03\x04\x03\x04\x08\x04\x04\x08\x10\x0b\t\x0b\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\xff\xc0\x00\x11\x08\x03\x1d\x05\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x01\x05\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\xff\xc4\x00X\x10\x00\x02\x01\x03\x03\x01\x06\x04\x03\x05\x04\x04\n',
# ...
